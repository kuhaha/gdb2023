# %%
# １．gensim モジュールをインストールする
# !pip install gensim
# Out:
# Requirement already satisfied: gensim in c:\local\python\python311\lib\site-packages (4.3.3)
# Requirement already satisfied: numpy<2.0,>=1.18.5 in c:\local\python\python311\lib\site-packages (from gensim) (1.23.5)
# Requirement already satisfied: scipy<1.14.0,>=1.7.0 in c:\local\python\python311\lib\site-packages (from gensim) (1.9.3)
# Requirement already satisfied: smart-open>=1.8.1 in c:\local\python\python311\lib\site-packages (from gensim) (6.3.0)

# %%
# ２．辞書を作成する
# 本ノートブックと同じフォルダに「livedoordic.txt」という名前のファイルが生成される
# !python corpus.py

# `from conllections import Mapping`あたりにエラーが出た場合、
# 下記のサイト参考にして、解決策を試してみる　
# https://github.com/Kyubyong/wordvectors/issues/28

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report
import corpus

# %%
# ３．辞書の読み込み
dictionary = corpus.get_dictionary(create_flg=False)

# 辞書の内容を表示する
for item in dictionary.items():
    print(item)
# Out:
# (1618, '!')
# (2105, '!!')
# (2127, '!?')
# (2120, '!?\u3000')
# (499, '"')
# (120, '%')
# (121, '&')
# (759, "'")
# (0, '(')
# (1, ')')
# (172, ')]')
# (1323, ')\u3000')
# (1035, ')」')
# (173, '+')
# (2, ',')
# (3, '/')
# (500, ':')
# (4, '://')
# (1351, '?')
# (174, '@')
# (175, '[')
# (344, ']')
# (1446, '_')
# (345, 'a')
# (558, 'ac')
# (1568, 'af')
# (2168, 'after')
# (1036, 'air')
# (1827, 'akb')
# (262, 'all')
# (5, 'amazon')
# (1654, 'amd')
# (176, 'android')
# (817, 'angrybirds')
# (122, 'app')
# (123, 'apple')
# (1217, 'aquos')
# (1971, 'ar')
# (1247, 'ascii')
# (2169, 'atem')
# (1302, 'au')
# (501, 'av')
# (1372, 'b')
# (2180, 'backnumber')
# (177, 'bci')
# (1408, 'bd')
# (502, 'best')
# (1683, 'bluetooth')
# (1909, 'book')
# (1697, 'bridge')
# (503, 'by')
# (1292, 'c')
# (760, 'cd')
# (346, 'ceo')
# (1822, 'chrome')
# (6, 'cl')
# (402, 'class')
# (1132, 'cm')
# (995, 'cmos')
# (7, 'co')
# (178, 'com')
# (263, 'copyright')
# (8, 'core')
# (9, 'cpu')
# (761, 'cube')
# (403, 'd')
# (347, 'data')
# (179, 'digi')
# (1801, 'digital')
# (1975, 'drive')
# (1619, 'dropbox')
# (932, 'ds')
# (933, 'dvd')
# (404, 'e')
# (818, 'eagle')
# (2124, 'effects')
# (1569, 'eos')
# (2057, 'ex')
# (264, 'excel')
# (265, 'explorer')
# (1698, 'express')
# (405, 'f')
# (504, 'facebook')
# (348, 'ffp')
# (1053, 'fi')
# (1823, 'firefox')
# (266, 'for')
# (406, 'g')
# (649, 'galaxy')
# (407, 'gb')
# (1409, 'geforce')
# (2170, 'genkosha')
# (2138, 'gh')
# (867, 'ghz')
# (650, 'google')
# (1570, 'gps')
# (1791, 'gpu')
# (408, 'gsdhc')
# (1757, 'gt')
# (1546, 'h')
# (996, 'hd')
# (1543, 'hdd')
# (1181, 'hdmi')
# (2159, 'hf')
# (1303, 'home')
# (559, 'hp')
# (10, 'html')
# (11, 'http')
# (2027, 'hulu')
# (12, 'i')
# (13, 'ic')
# (505, 'id')
# (267, 'ie')
# (651, 'ii')
# (1571, 'iii')
# (762, 'in')
# (1037, 'intel')
# (2118, 'intensity')
# (728, 'ios')
# (124, 'ipad')
# (1724, 'ipod')
# (1330, 'is')
# (14, 'it')
# (1009, 'itunes')
# (2160, 'ivis')
# (1699, 'ivy')
# (1331, 'j')
# (1557, 'japan')
# (15, 'jp')
# (349, 'k')
# (180, 'kamikura')
# (1010, 'katsuosh')
# (729, 'kddi')
# (1655, 'kg')
# (181, 'kindle')
# (2110, 'kobo')
# (2132, 'komatsu')
# (1218, 'l')
# (934, 'lan')
# (868, 'led')
# (1746, 'linux')
# (125, 'lion')
# (1527, 'live')
# (268, 'livedoor')
# (409, 'lte')
# (601, 'm')
# (16, 'mac')
# (1038, 'macbook')
# (1544, 'macos')
# (1097, 'mah')
# (449, 'masason')
# (1269, 'mb')
# (1054, 'mbps')
# (1747, 'media')
# (410, 'medias')
# (1700, 'mini')
# (1966, 'mixi')
# (2133, 'miyuki')
# (411, 'mm')
# (997, 'mobile')
# (2112, 'mook')
# (126, 'mountain')
# (2015, 'movie')
# (182, 'mp')
# (1558, 'ms')
# (412, 'n')
# (17, 'nec')
# (2098, 'nex')
# (413, 'next')
# (2005, 'nhk')
# (2055, 'niconico')
# (269, 'no')
# (652, 'note')
# (1332, 'ntt')
# (1410, 'nvidia')
# (350, 'o')
# (127, 'of')
# (1098, 'office')
# (1133, 'ok')
# (450, 'on')
# (1464, 'one')
# (18, 'os')
# (414, 'p')
# (19, 'pc')
# (1304, 'pdf')
# (2161, 'perfect')
# (653, 'phone')
# (1794, 'php')
# (654, 'pro')
# (183, 'ps')
# (1373, 'qr')
# (655, 'r')
# (819, 'rainbowapps')
# (1484, 'ray')
# (1219, 'regza')
# (2171, 'report')
# (270, 'reserved')
# (1679, 'retina')
# (935, 'review')
# (271, 'rights')
# (763, 'ring')
# (656, 's')
# (2157, 'salon')
# (1733, 'sata')
# (1231, 'sc')
# (1420, 'sd')
# (415, 'sdhc')
# (416, 'series')
# (1232, 'sh')
# (978, 'sns')
# (848, 'softbank')
# (657, 'sony')
# (1873, 'special')
# (20, 'ssd')
# (1233, 'station')
# (128, 'store')
# (2172, 'switcher')
# (602, 't')
# (1099, 'tab')
# (351, 'tablet')
# (352, 'tb')
# (129, 'the')
# (1680, 'thunderbolt')
# (1039, 'to')
# (2008, 'togetter')
# (2093, 'top')
# (1589, 'touch')
# (417, 'transcend')
# (418, 'ts')
# (1908, 'tumblr')
# (21, 'tv')
# (22, 'twitter')
# (1411, 'u')
# (1438, 'ui')
# (911, 'ultrabook')
# (1040, 'ultrabooker')
# (1772, 'url')
# (506, 'us')
# (353, 'usb')
# (2101, 'users')
# (1547, 'v')
# (184, 'vita')
# (2039, 'vs')
# (764, 'w')
# (507, 'web')
# (1055, 'wi')
# (1056, 'wifi')
# (185, 'windows')
# (1293, 'with')
# (1946, 'wooo')
# (272, 'word')
# (273, 'www')
# (23, 'x')
# (1116, 'xbox')
# (419, 'xi')
# (274, 'xp')
# (420, 'xperia')
# (1620, 'yahoo')
# (1439, 'youtube')
# (1455, 'z')
# (1862, 'zero')
# (603, 'zigsow')
# (1955, '—')
# (1294, '−')
# (1771, '♪')
# (2186, '\u3000−\u3000')
# (130, '〜')
# (186, 'あたり')
# (1195, 'あと')
# (508, 'あなた')
# (1581, 'あまり')
# (1041, 'いかが')
# (187, 'いくつ')
# (1495, 'いずれ')
# (1916, 'いち')
# (1234, 'いつ')
# (1940, 'いつか')
# (1656, 'いま')
# (1496, 'いろいろ')
# (1134, 'いわく')
# (1235, 'うえ')
# (1447, 'うち')
# (1248, 'ぉっくす')
# (1572, 'おかげ')
# (2090, 'おしゃれ')
# (820, 'おすすめ')
# (1548, 'お供')
# (604, 'お気に入り')
# (188, 'お知らせ')
# (1497, 'お話')
# (1374, 'お金')
# (1929, 'お願い')
# (1352, 'かなり')
# (1944, 'か月')
# (1471, 'がち')
# (1843, 'きっかけ')
# (2058, 'きれい')
# (275, 'ここ')
# (1375, 'こちら')
# (189, 'これら')
# (658, 'ごと')
# (869, 'さまざま')
# (1641, 'さらい')
# (451, 'さん')
# (1205, 'すぎ')
# (560, 'すべて')
# (452, 'そう')
# (1694, 'そこ')
# (1863, 'そのもの')
# (730, 'その他')
# (765, 'その後')
# (453, 'それ')
# (659, 'それぞれ')
# (190, 'それなり')
# (1664, 'それら')
# (1011, 'たくさん')
# (766, 'たち')
# (1117, 'たび')
# (1249, 'ちゃん')
# (1250, 'つかさ')
# (24, 'つぶやき')
# (276, 'とき')
# (660, 'ところ')
# (131, 'どこ')
# (1353, 'どちら')
# (1964, 'どっち')
# (25, 'どれ')
# (1604, 'なか')
# (509, 'なに')
# (26, 'ならでは')
# (1605, 'なん')
# (2083, 'ぬいぐるみ')
# (605, 'はじめ')
# (561, 'はず')
# (1812, 'はるか')
# (1118, 'ひとつ')
# (1498, 'ひとり')
# (1911, 'びっくり')
# (1899, 'ぴったり')
# (1749, 'ぶり')
# (1174, 'ほう')
# (606, 'ほか')
# (1631, 'まとめ')
# (870, 'まま')
# (1499, 'みたい')
# (849, 'みんな')
# (2017, 'め')
# (1528, 'もと')
# (132, 'もの')
# (1251, 'ゅうす')
# (1081, 'ら')
# (191, 'わけ')
# (454, 'ん')
# (998, 'アイコ')
# (277, 'アイコン')
# (731, 'アイテム')
# (2035, 'アイドル')
# (1376, 'アイ・オー・データ機器')
# (732, 'アカウント')
# (1252, 'アキバ')
# (1220, 'アク')
# (2052, 'アクセサリー')
# (959, 'アクセス')
# (871, 'アシスタント')
# (1196, 'アジア')
# (1758, 'アスク')
# (1549, 'アダプタ')
# (562, 'アダプター')
# (133, 'アップ')
# (1621, 'アップデート')
# (134, 'アップル')
# (1725, 'アップルストア')
# (1951, 'アナタ')
# (1987, 'アナログ')
# (960, 'アニメ')
# (1465, 'アピール')
# (192, 'アプリ')
# (135, 'アプリケーション')
# (821, 'アプリランキング')
# (2066, 'アマゾン')
# (1726, 'アメリカ')
# (2081, 'アンドロイド')
# (455, 'アート')
# (1182, 'イオン')
# (1500, 'イギリス')
# (1135, 'イケショップ')
# (1221, 'イベント')
# (278, 'イメージ')
# (1853, 'イヤ')
# (1903, 'イラスト')
# (2097, 'イルミネーション')
# (1802, 'イン')
# (27, 'インク')
# (136, 'インストール')
# (1773, 'インタビュー')
# (1183, 'インター')
# (510, 'インターネット')
# (1868, 'インターフェース')
# (421, 'インチ')
# (2059, 'インテリア')
# (28, 'インテル')
# (279, 'ウィンドウ')
# (1594, 'ウイルス')
# (1665, 'ウェブサイト')
# (2122, 'ウォーク')
# (511, 'ウド')
# (1136, 'ウルトラ')
# (1874, 'エア')
# (1993, 'エアコン')
# (512, 'エコ')
# (280, 'エヌプラス')
# (1595, 'エネルギー')
# (29, 'エプソン')
# (1057, 'エリア')
# (999, 'エンジン')
# (1780, 'オシャレ')
# (1222, 'オス')
# (822, 'オススメ')
# (1761, 'オフ')
# (1100, 'オフィス')
# (947, 'オプション')
# (872, 'オリジナル')
# (1448, 'オリンピック')
# (1930, 'オン')
# (1101, 'オンライン')
# (1878, 'オーストラリア')
# (1184, 'オーディオ')
# (1529, 'オート')
# (1421, 'オーバー')
# (1042, 'オープン')
# (2145, 'カシオ')
# (563, 'カスタマイズ')
# (1175, 'カッコ')
# (1449, 'カット')
# (661, 'カテゴリ')
# (1058, 'カバー')
# (1000, 'カメラ')
# (873, 'カラー')
# (30, 'カートリッジ')
# (422, 'カード')
# (1994, 'カーナビ')
# (1333, 'カ月')
# (1137, 'ガ')
# (2134, 'ガイガーカウンター')
# (1377, 'ガイド')
# (1854, 'ガイドブック')
# (912, 'ガラス')
# (1422, 'キット')
# (2156, 'キャノン')
# (193, 'キャノンインクタンク')
# (2018, 'キャラ')
# (1936, 'キャラクター')
# (850, 'キャリア')
# (354, 'キャンペーン')
# (194, 'キヤノン')
# (1176, 'キレイ')
# (1270, 'キン')
# (913, 'キー')
# (281, 'キーボード')
# (1774, 'キーワード')
# (767, 'ギャラリー')
# (1324, 'クイズ')
# (31, 'クチコミ')
# (513, 'クラ')
# (1059, 'クラス')
# (1001, 'クリア')
# (456, 'クリエイティブ')
# (662, 'クリスマス')
# (282, 'クリック')
# (1423, 'クロック')
# (1138, 'グッズ')
# (1931, 'グラフ')
# (1596, 'グラフィック')
# (1412, 'グラフィックス')
# (1875, 'グラボ')
# (457, 'グループ')
# (961, 'グーグル')
# (2129, 'ケア')
# (663, 'ケース')
# (2075, 'ケータイ')
# (874, 'ケーブル')
# (979, 'ゲット')
# (195, 'ゲーム')
# (823, 'ゲームアプリコース')
# (1236, 'コア')
# (514, 'コスト')
# (1043, 'コストパフォーマンス')
# (2104, 'コツ')
# (1550, 'コネクタ')
# (1695, 'コピー')
# (1253, 'コマ')
# (1012, 'コマンド')
# (1501, 'コミュニケーション')
# (458, 'コメント')
# (914, 'コラボ')
# (1551, 'コレ')
# (1466, 'コンセプト')
# (1139, 'コンセント')
# (196, 'コンテンツ')
# (1573, 'コンデジ')
# (1456, 'コントラスト')
# (137, 'コントロール')
# (1073, 'コンパクト')
# (138, 'コンピュータ')
# (1354, 'コンピューター')
# (824, 'コース')
# (607, 'コード')
# (1783, 'コーナー')
# (283, 'サイズ')
# (139, 'サイト')
# (1855, 'サイフケータイ')
# (355, 'サポート')
# (1485, 'サムスン')
# (2094, 'サロン')
# (936, 'サーバー')
# (197, 'サービス')
# (664, 'シェア')
# (515, 'システム')
# (1892, 'シャッター')
# (198, 'シャープ')
# (1666, 'ショッピング')
# (851, 'ショップ')
# (1803, 'ショー')
# (32, 'シリーズ')
# (875, 'シルバー')
# (825, 'シンプル')
# (356, 'シーズン')
# (948, 'シート')
# (423, 'シーン')
# (1140, 'ジェット')
# (608, 'ジグソー')
# (1261, 'ジャパン')
# (284, 'ジャム')
# (1554, 'ジャンプ')
# (1921, 'ジャンル')
# (140, 'ジョブズ')
# (876, 'スイッチ')
# (1667, 'スキャン')
# (1828, 'スクリーン')
# (285, 'スクロール')
# (1958, 'スケジュール')
# (1714, 'ススメ')
# (1102, 'スタイリッシュ')
# (459, 'スタイル')
# (1141, 'スタッフ')
# (1237, 'スタンダード')
# (1142, 'スタンド')
# (1044, 'スタート')
# (1119, 'スティーブ')
# (1956, 'ステップ')
# (1923, 'ステレオ')
# (1325, 'ステージ')
# (1942, 'ストリーミング')
# (1238, 'ストレス')
# (1103, 'ストレージ')
# (980, 'ストーリー')
# (1185, 'スピーカー')
# (1002, 'スピード')
# (1849, 'スペシャル')
# (915, 'スペック')
# (1074, 'スペース')
# (1305, 'スポット')
# (2028, 'スポーツ')
# (609, 'スマ')
# (424, 'スマホ')
# (33, 'スマート')
# (665, 'スマートフォン')
# (1295, 'スムーズ')
# (425, 'スリム')
# (1223, 'スロット')
# (826, 'スーパー')
# (1893, 'ズーム')
# (1424, 'ズームレンズ')
# (34, 'セキュリティ')
# (35, 'セット')
# (1597, 'セミナー')
# (1627, 'セル')
# (916, 'センサー')
# (141, 'センター')
# (142, 'ソニー')
# (2143, 'ソファ')
# (36, 'ソフト')
# (143, 'ソフトウェア')
# (460, 'ソフトバンク')
# (1355, 'ソーシャル')
# (2102, 'ソーシャルメディア')
# (610, 'ソーシャルレビューコミュニティ')
# (1707, 'ソーラー')
# (1186, 'タイ')
# (1606, 'タイトル')
# (37, 'タイプ')
# (1950, 'タイミング')
# (1826, 'タイム')
# (1271, 'タグ')
# (1555, 'タスク')
# (827, 'タッチ')
# (1991, 'タッチパネル')
# (1472, 'タップ')
# (949, 'タブ')
# (357, 'タブレット')
# (1378, 'タレント')
# (2054, 'タワー')
# (1959, 'ダイレクト')
# (1804, 'ダウン')
# (516, 'ダウンロード')
# (1835, 'ダブル')
# (1701, 'チップ')
# (828, 'チャンス')
# (1912, 'チャンネル')
# (1809, 'チューナー')
# (358, 'チーム')
# (1786, 'ツイッター')
# (1314, 'ツイート')
# (286, 'ツール')
# (517, 'テキスト')
# (287, 'テクニック')
# (1727, 'テクノロジー')
# (564, 'テスト')
# (38, 'テレビ')
# (768, 'テーマ')
# (1545, 'ディスク')
# (426, 'ディスプレイ')
# (611, 'デザイン')
# (199, 'デジ')
# (769, 'デジカメ')
# (39, 'デジタル')
# (40, 'デスク')
# (518, 'デバイス')
# (1239, 'デュアル')
# (1262, 'データ')
# (41, 'トップ')
# (962, 'トップページ')
# (1120, 'トラブル')
# (427, 'トランセンド・ジャパン')
# (612, 'トレンド')
# (2038, 'トーク')
# (2178, 'ト書き')
# (963, 'ドイツ')
# (1622, 'ドキュメント')
# (428, 'ドコモ')
# (1104, 'ドット')
# (937, 'ドライブ')
# (1206, 'ドラッグ')
# (964, 'ドラマ')
# (613, 'ドリーム')
# (519, 'ドル')
# (1995, 'ナビ')
# (1530, 'ニコ')
# (2153, 'ニコン')
# (1121, 'ニュース')
# (666, 'ニーズ')
# (144, 'ネタ')
# (461, 'ネット')
# (42, 'ネットワーク')
# (1486, 'ノイズ')
# (1753, 'ノウハウ')
# (43, 'ノート')
# (1379, 'ハイ')
# (1425, 'ハイエンド')
# (1380, 'ハイビジョン')
# (44, 'ハイブリッド')
# (288, 'ハウス')
# (1767, 'ハード')
# (200, 'ハードウェア')
# (359, 'ハードディスク')
# (1272, 'バイト')
# (45, 'バック')
# (1668, 'バックアップ')
# (1105, 'バッテリ')
# (289, 'バッテリー')
# (1487, 'バラエティ')
# (1917, 'バランス')
# (1240, 'バンク')
# (1315, 'バンド')
# (290, 'バー')
# (1013, 'バージョン')
# (429, 'バージョンアップ')
# (1273, 'パケット')
# (1014, 'パスワード')
# (46, 'パソコン')
# (2000, 'パターン')
# (201, 'パック')
# (360, 'パッケージ')
# (565, 'パナソニック')
# (917, 'パネル')
# (1381, 'パフォーマンス')
# (47, 'パワフル')
# (1382, 'パワー')
# (48, 'パワーアップ')
# (1426, 'パーツ')
# (520, 'パーティ')
# (667, 'ヒット')
# (829, 'ヒント')
# (2147, 'ヒーター')
# (430, 'ビジネス')
# (1413, 'ビット')
# (770, 'ビデオ')
# (1894, 'ビデオカメラ')
# (614, 'ビューアー')
# (2049, 'ビル')
# (1427, 'ピックアップ')
# (1106, 'ピンク')
# (1895, 'ピント')
# (202, 'ファイル')
# (1122, 'ファン')
# (1592, 'フィルム')
# (1187, 'フェイス')
# (615, 'フォト')
# (1015, 'フォルダ')
# (291, 'フォルダー')
# (49, 'フォン')
# (521, 'フォーカス')
# (1274, 'フォーマット')
# (2114, 'フジテレビ')
# (361, 'フラストレーション')
# (50, 'フラッシュ')
# (362, 'フリー')
# (668, 'フル')
# (1296, 'フレーム')
# (616, 'ブック')
# (1016, 'ブラウザ')
# (877, 'ブラック')
# (2166, 'ブラックマジックデザイン')
# (363, 'ブランド')
# (1188, 'ブルー')
# (771, 'ブレ')
# (292, 'ブログ')
# (1559, 'ブース')
# (2126, 'ブーム')
# (2100, 'プライバシー')
# (51, 'プラス')
# (203, 'プラットフォーム')
# (1060, 'プラン')
# (938, 'プリンター')
# (1356, 'プレイ')
# (462, 'プレゼン')
# (617, 'プレゼント')
# (918, 'プレミアム')
# (1684, 'プレーヤー')
# (364, 'プロ')
# (1647, 'プログラム')
# (1560, 'プロジェクター')
# (1850, 'プロジェクト')
# (1681, 'プロセス')
# (52, 'プロセッサ')
# (1224, 'プロセッサー')
# (772, 'プロフィール')
# (1856, 'ヘッド')
# (1813, 'ヘッドホン')
# (773, 'ベース')
# (669, 'ペン')
# (293, 'ページ')
# (618, 'ホ')
# (1650, 'ホット')
# (1143, 'ホルダー')
# (1107, 'ホワイト')
# (53, 'ホーム')
# (878, 'ホームページ')
# (1844, 'ホール')
# (294, 'ボタン')
# (1754, 'ボックス')
# (431, 'ボディ')
# (1702, 'ボード')
# (54, 'ポイント')
# (432, 'ポケット')
# (204, 'ポータブル')
# (1383, 'ポート')
# (1189, 'マイク')
# (1561, 'マイクロソフト')
# (295, 'マウス')
# (1869, 'マウント')
# (1703, 'マザー')
# (1384, 'マシン')
# (830, 'マスター')
# (2144, 'マッサージ')
# (831, 'マリオ')
# (1715, 'マル')
# (205, 'マルチ')
# (852, 'マン')
# (1913, 'マンガ')
# (1306, 'マーク')
# (1968, 'マーケティング')
# (1810, 'ミス')
# (2181, 'ミタ')
# (1900, 'ミドル')
# (1108, 'ミニ')
# (145, 'ミラー')
# (1728, 'ミリ')
# (950, 'ムダ')
# (1924, 'ムービー')
# (1657, 'メイン')
# (2037, 'メガネ')
# (146, 'メッセージ')
# (1241, 'メディア')
# (951, 'メニュー')
# (147, 'メモ')
# (1190, 'メモリ')
# (1590, 'メモリー')
# (1144, 'メリット')
# (148, 'メンバー')
# (670, 'メーカー')
# (296, 'メール')
# (2162, 'モテ')
# (55, 'モデル')
# (365, 'モニター')
# (619, 'モノ')
# (522, 'モバイル')
# (1242, 'モバステ')
# (879, 'モード')
# (1901, 'ユニット')
# (1762, 'ユニーク')
# (56, 'ユーザー')
# (1651, 'ライター')
# (880, 'ライト')
# (1824, 'ライフ')
# (1787, 'ライフスタイル')
# (206, 'ライフハック')
# (1531, 'ライブ')
# (1414, 'ライン')
# (671, 'ラインナップ')
# (1191, 'ラジオ')
# (1357, 'ランキング')
# (620, 'リアル')
# (1623, 'リアルタイム')
# (774, 'リコー')
# (775, 'リコーフォトギャラリー')
# (1358, 'リスト')
# (1145, 'リビング')
# (621, 'リモコン')
# (2069, 'リラックス')
# (149, 'リリース')
# (832, 'リンク')
# (150, 'リング')
# (207, 'リーダー')
# (1061, 'ルーター')
# (622, 'レ')
# (1146, 'レア')
# (366, 'レグザ')
# (1532, 'レコーダー')
# (1910, 'レス')
# (881, 'レッド')
# (367, 'レノボ')
# (57, 'レビュー')
# (1574, 'レフ')
# (833, 'レベル')
# (623, 'レポート')
# (1902, 'レンジ')
# (1575, 'レンズ')
# (1947, 'レンタル')
# (1017, 'ログイン')
# (368, 'ロゴ')
# (672, 'ロック')
# (2036, 'ロボット')
# (776, 'ロンドン')
# (1062, 'ロー')
# (1716, 'ローカル')
# (1624, 'ロード')
# (2188, 'ローラ')
# (1763, 'ワイド')
# (882, 'ワイヤレス')
# (297, 'ワザ')
# (298, 'ワン')
# (1811, 'ワンセグ')
# (1836, 'ワンタッチ')
# (1003, 'ン')
# (673, 'ヶ月')
# (1385, '・')
# (1582, 'ー')
# (151, '一')
# (834, '一つ')
# (853, '一体')
# (883, '一定')
# (674, '一方')
# (733, '一時')
# (463, '一番')
# (1533, '一眼')
# (1675, '一瞬')
# (854, '一緒')
# (566, '一般')
# (1502, '一見')
# (1708, '一覧')
# (734, '一部')
# (675, '万')
# (777, '三')
# (58, '上')
# (1147, '上下')
# (919, '上位')
# (208, '上倉')
# (1629, '上旬')
# (1734, '上昇')
# (1254, '上映')
# (1648, '上記')
# (1861, '上部')
# (855, '下')
# (884, '下旬')
# (464, '下記')
# (1598, '不可能')
# (59, '不安')
# (778, '不思議')
# (1450, '不明')
# (1082, '不正')
# (60, '不満')
# (885, '不要')
# (1359, '不足')
# (676, '世代')
# (677, '世界')
# (1488, '世界中')
# (1792, '両方')
# (1075, '両立')
# (567, '並み')
# (568, '中国')
# (779, '中央')
# (2173, '中平')
# (678, '中心')
# (920, '中旬')
# (1676, '中継')
# (299, '中身')
# (569, '主')
# (1658, '主催')
# (1489, '主流')
# (2177, '主演')
# (61, '主要')
# (1795, '乗')
# (2149, '乾燥')
# (679, '予定')
# (1083, '予想')
# (856, '予約')
# (465, '事')
# (2125, '事件')
# (1906, '事前')
# (1316, '事実')
# (466, '事故')
# (680, '事業')
# (1503, '二')
# (1018, '互換')
# (2024, '五')
# (2130, '亜紀子')
# (735, '交換')
# (369, '人々')
# (1845, '人数')
# (62, '人気')
# (1709, '人物')
# (467, '人生')
# (1766, '人間')
# (468, '今')
# (209, '今回')
# (1123, '今夜')
# (681, '今年')
# (1729, '今度')
# (210, '今後')
# (523, '今日')
# (1888, '今月')
# (1769, '今週')
# (1207, '仕事')
# (1814, '仕方')
# (524, '仕様')
# (1642, '仕組み')
# (211, '他')
# (2009, '他人')
# (682, '他社')
# (370, '付')
# (921, '付き')
# (1019, '付け')
# (1148, '付属')
# (2047, '付録')
# (1275, '代')
# (1628, '代わり')
# (469, '代表')
# (152, '以上')
# (63, '以下')
# (1556, '以前')
# (212, '以外')
# (1805, '以来')
# (952, '以降')
# (981, '仲間')
# (1479, '件')
# (1360, '任天堂')
# (1045, '企業')
# (780, '企画')
# (982, '会')
# (1562, '会員')
# (1473, '会場')
# (300, '会社')
# (1857, '会話')
# (525, '会議')
# (1999, '会長')
# (1149, '伝説')
# (371, '位')
# (1285, '位置')
# (1467, '低下')
# (886, '体')
# (1263, '体制')
# (1896, '体型')
# (1504, '体感')
# (2136, '体重')
# (1440, '体験')
# (470, '何')
# (1759, '余裕')
# (1607, '作')
# (1307, '作り')
# (2117, '作例')
# (781, '作品')
# (1505, '作家')
# (301, '作成')
# (1150, '作業')
# (1020, '使い')
# (213, '使い勝手')
# (302, '使い方')
# (64, '使用')
# (1784, '例')
# (1415, '供給')
# (1441, '価値')
# (214, '価格')
# (215, '便利')
# (303, '保存')
# (216, '保証')
# (1593, '保護')
# (1815, '信号')
# (887, '信頼')
# (1858, '修正')
# (1608, '俺')
# (1609, '個')
# (65, '個人')
# (1474, '個別')
# (1506, '個性')
# (471, '倍')
# (983, '値')
# (2113, '値下げ')
# (1932, '値段')
# (736, '停止')
# (2115, '健康')
# (1490, '側')
# (922, '傷')
# (1334, '傾向')
# (472, '僕')
# (683, '億')
# (1507, '優先')
# (1475, '元')
# (1864, '元気')
# (433, '充実')
# (1151, '充電')
# (304, '先')
# (526, '先日')
# (434, '先行')
# (1730, '先述')
# (1770, '先週')
# (1335, '光')
# (1659, '光学')
# (1021, '克彦')
# (1883, '入り')
# (305, '入力')
# (306, '入手')
# (1428, '入賞')
# (372, '全て')
# (307, '全体')
# (2013, '全員')
# (1063, '全国')
# (1937, '全部')
# (527, '公式')
# (737, '公表')
# (153, '公開')
# (1084, '共同')
# (939, '共有')
# (217, '共通')
# (1643, '具体')
# (373, '内')
# (1085, '内容')
# (1416, '内蔵')
# (1124, '内部')
# (1534, '再現')
# (1297, '再生')
# (624, '写真')
# (2089, '冬')
# (1197, '冷却')
# (1610, '冷蔵庫')
# (1208, '処理')
# (1109, '出力')
# (1152, '出張')
# (1535, '出演')
# (1508, '出版')
# (66, '出荷')
# (625, '分')
# (1276, '分の')
# (1361, '分析')
# (1336, '分野')
# (1153, '切れ')
# (1022, '列')
# (684, '初')
# (984, '初回')
# (1023, '初心者')
# (1960, '初日')
# (67, '初期')
# (685, '判断')
# (738, '判明')
# (686, '別')
# (308, '利夫')
# (570, '利点')
# (1277, '制')
# (309, '制作')
# (1704, '制御')
# (528, '制限')
# (953, '削除')
# (435, '前')
# (1750, '前回')
# (923, '前後')
# (1972, '前田')
# (68, '割')
# (2123, '割り')
# (1451, '割合')
# (1004, '劇的')
# (69, '力')
# (1417, '加工')
# (2140, '加湿')
# (154, '加速')
# (70, '効果')
# (888, '効率')
# (1326, '勉強')
# (2010, '動')
# (1563, '動き')
# (218, '動作')
# (687, '動向')
# (1005, '動画')
# (985, '勝手')
# (626, '募集')
# (688, '勢い')
# (1934, '勧め')
# (71, '化')
# (782, '区')
# (1611, '十')
# (689, '十分')
# (739, '千')
# (740, '午前')
# (2045, '午後')
# (1024, '半分')
# (783, '卒業')
# (1865, '協会')
# (1405, '協力')
# (965, '単位')
# (1278, '単純')
# (1509, '印刷')
# (1177, '印象')
# (1669, '危険')
# (741, '原因')
# (473, '原発')
# (1386, '原稿')
# (835, '参入')
# (529, '参加')
# (1670, '参照')
# (1429, '参考')
# (1362, '友人')
# (1363, '友達')
# (2021, '反対')
# (1961, '反応')
# (1884, '反映')
# (742, '反論')
# (1632, '収入')
# (889, '収納')
# (2128, '収録')
# (1957, '収集')
# (1760, '取り扱い')
# (530, '取り組み')
# (1806, '取引')
# (743, '取得')
# (1510, '取材')
# (374, '取締役')
# (784, '受付')
# (1209, '受信')
# (836, '受講')
# (531, '受賞')
# (1639, '口')
# (627, '口コミ')
# (628, '台')
# (690, '台数')
# (1710, '台湾')
# (1476, '右')
# (1691, '右側')
# (1086, '号')
# (691, '各国')
# (692, '各社')
# (219, '各種')
# (1879, '合成')
# (1775, '合計')
# (857, '同士')
# (1076, '同時')
# (693, '同期')
# (924, '同様')
# (474, '同氏')
# (72, '同社')
# (220, '同等')
# (310, '名')
# (966, '名前')
# (73, '向け')
# (1468, '向上')
# (1919, '周り')
# (1511, '周囲')
# (785, '周年')
# (967, '周波数')
# (1387, '周辺')
# (2019, '味')
# (1154, '味方')
# (1388, '品')
# (571, '品質')
# (1406, '員')
# (1796, '哲学')
# (74, '商品')
# (2046, '商戦')
# (221, '問題')
# (694, '営業')
# (1442, '噂')
# (1552, '器')
# (2146, '器具')
# (1808, '四')
# (940, '回')
# (1671, '回復')
# (1452, '回答')
# (1279, '回線')
# (890, '回転')
# (1599, '回避')
# (1889, '団体')
# (1649, '図')
# (1155, '固定')
# (572, '国')
# (75, '国内')
# (2029, '国産')
# (1308, '国際')
# (1198, '圏')
# (1457, '土')
# (695, '圧倒的')
# (1717, '圧縮')
# (1880, '在住')
# (629, '地')
# (1389, '地上')
# (1309, '地域')
# (1337, '地方')
# (1199, '地球')
# (375, '型')
# (1685, '型番')
# (222, '執筆')
# (837, '基本')
# (1512, '堪能')
# (696, '報告')
# (1807, '報道')
# (573, '場')
# (223, '場合')
# (786, '場所')
# (1338, '増加')
# (2108, '壁紙')
# (1711, '声')
# (1686, '売')
# (1364, '売り上げ')
# (2073, '売れ筋')
# (224, '変化')
# (1286, '変換')
# (311, '変更')
# (155, '夏')
# (1837, '夏休み')
# (376, '外')
# (1064, '外出')
# (1859, '外国')
# (1192, '外部')
# (76, '多く')
# (697, '多数')
# (1904, '夜')
# (1576, '夜景')
# (475, '夢')
# (77, '大')
# (1317, '大丈夫')
# (1200, '大事')
# (1318, '大人')
# (1838, '大人気')
# (858, '大切')
# (1243, '大型')
# (1319, '大変')
# (476, '大好き')
# (532, '大学')
# (1025, '大島')
# (891, '大幅')
# (1825, '大手')
# (1735, '大量')
# (1962, '大阪')
# (1866, '大震災')
# (1977, '天国')
# (2003, '天気')
# (1764, '太陽')
# (1797, '太陽光')
# (312, '奈知')
# (377, '契約')
# (1722, '奥行き')
# (1587, '女')
# (1788, '女の子')
# (2079, '女優')
# (378, '女子')
# (1513, '女性')
# (630, '好き')
# (1736, '好み')
# (1768, '好評')
# (968, '如何')
# (1514, '姿')
# (379, '姿勢')
# (2182, '婦')
# (313, '子')
# (1983, '子ども')
# (1390, '子供')
# (969, '存在')
# (1978, '季節')
# (1846, '学')
# (1847, '学校')
# (1339, '学生')
# (631, '学習')
# (477, '孫')
# (1458, '宇宙')
# (1870, '安')
# (1943, '安価')
# (1600, '安全')
# (892, '安定')
# (78, '安心')
# (1287, '完了')
# (156, '完全')
# (1748, '完成')
# (1046, '定期')
# (1925, '定番')
# (1453, '定着')
# (1065, '定額')
# (1687, '実')
# (2032, '実力')
# (574, '実感')
# (380, '実施')
# (436, '実機')
# (437, '実現')
# (1110, '実用')
# (1365, '実績')
# (1459, '実行')
# (1430, '実践')
# (1280, '実験')
# (1881, '客観')
# (1677, '宣伝')
# (1310, '宣言')
# (1633, '室')
# (533, '家')
# (1156, '家庭')
# (2183, '家政')
# (941, '家族')
# (632, '家電')
# (1077, '容量')
# (1660, '対抗')
# (2040, '対決')
# (1320, '対策')
# (633, '対象')
# (225, '専用')
# (1047, '専門')
# (226, '将来')
# (79, '導入')
# (893, '小型')
# (1765, '小売')
# (2087, '少女')
# (1480, '局')
# (1737, '届け')
# (1973, '屋')
# (1460, '屋外')
# (787, '展')
# (438, '展示')
# (698, '展開')
# (1264, '層')
# (314, '岡本')
# (80, '工場')
# (1210, '工夫')
# (1477, '左')
# (1692, '左側')
# (894, '左右')
# (1905, '巨大')
# (699, '差')
# (1712, '市')
# (700, '市場')
# (1583, '希望')
# (895, '帯')
# (1311, '常識')
# (1157, '幅')
# (942, '平均')
# (2103, '年内')
# (381, '年度')
# (1612, '年末')
# (2164, '年末年始')
# (534, '年間')
# (859, '幸せ')
# (535, '広告')
# (1255, '店')
# (1661, '店舗')
# (925, '店頭')
# (896, '度')
# (81, '式')
# (1831, '弱')
# (1244, '強力')
# (82, '強化')
# (1890, '強調')
# (1469, '弾')
# (1366, '当たり前')
# (1066, '当初')
# (1515, '当日')
# (1516, '当時')
# (1431, '形')
# (1026, '形式')
# (1738, '形状')
# (744, '影響')
# (1851, '役')
# (970, '彼')
# (1517, '彼女')
# (1591, '待望')
# (227, '後')
# (701, '後半')
# (745, '従来')
# (1211, '得')
# (1158, '復活')
# (1640, '復興')
# (2023, '微妙')
# (575, '徹底')
# (1407, '心')
# (746, '心配')
# (315, '必要')
# (1789, '必見')
# (228, '必須')
# (1048, '応募')
# (478, '応援')
# (83, '快適')
# (860, '思い')
# (1601, '急増')
# (702, '急速')
# (229, '性')
# (84, '性能')
# (1945, '恋人')
# (703, '恐れ')
# (2174, '悠里')
# (1553, '悩み')
# (536, '想像')
# (747, '想定')
# (1027, '意味')
# (1229, '意外')
# (479, '意見')
# (576, '意識')
# (382, '愛')
# (704, '感')
# (1518, '感じ')
# (383, '感動')
# (1006, '感度')
# (1049, '感想')
# (1178, '感覚')
# (705, '成功')
# (838, '成長')
# (706, '戦略')
# (788, '所')
# (1312, '所有')
# (1159, '手')
# (1078, '手のひら')
# (2119, '手入れ')
# (1577, '手持ち')
# (1839, '手段')
# (707, '手軽')
# (316, '手間')
# (2064, '批判')
# (317, '技')
# (708, '技術')
# (318, '把握')
# (709, '投入')
# (1461, '投稿')
# (1935, '投資')
# (1705, '披露')
# (789, '担当')
# (1067, '拡大')
# (1111, '拡張')
# (1584, '拡散')
# (861, '持ち')
# (577, '持ち運び')
# (1391, '指')
# (319, '指定')
# (1432, '挑戦')
# (1644, '据え置き')
# (1696, '掃除')
# (710, '採用')
# (384, '接続')
# (537, '掲載')
# (157, '提供')
# (954, '提出')
# (748, '提携')
# (85, '提案')
# (86, '搭載')
# (385, '携帯')
# (790, '撮影')
# (230, '操作')
# (1265, '支援')
# (897, '改善')
# (2092, '放射線')
# (1125, '放送')
# (1281, '放題')
# (1938, '教育')
# (1974, '敦子')
# (634, '数')
# (1288, '数値')
# (578, '数字')
# (1212, '整理')
# (2063, '文')
# (1519, '文化')
# (635, '文字')
# (1245, '文字通り')
# (1798, '文庫')
# (1112, '文書')
# (636, '文章')
# (538, '料')
# (1613, '料理')
# (1068, '料金')
# (2041, '斜め')
# (1313, '新た')
# (2076, '新作')
# (1662, '新型')
# (1776, '新聞')
# (231, '新規')
# (87, '方')
# (1478, '方向')
# (898, '方式')
# (88, '方法')
# (1160, '旅行')
# (1739, '既存')
# (386, '日々')
# (1740, '日常')
# (232, '日本')
# (1867, '日本テレビ')
# (480, '日本人')
# (539, '日本語')
# (1948, '日立')
# (1848, '日間')
# (158, '明らか')
# (1970, '明日')
# (1367, '昔')
# (1028, '星')
# (439, '映像')
# (791, '映画')
# (89, '春')
# (159, '昨年')
# (540, '昨日')
# (579, '時')
# (387, '時代')
# (711, '時期')
# (1069, '時点')
# (160, '時間')
# (712, '普及')
# (1688, '普段')
# (1520, '普通')
# (1922, '曲')
# (90, '更新')
# (955, '書')
# (1723, '書き込み')
# (233, '書籍')
# (956, '書類')
# (1832, '最低')
# (1741, '最先端')
# (161, '最初')
# (580, '最大')
# (986, '最強')
# (1289, '最後')
# (91, '最新')
# (581, '最終')
# (1321, '最近')
# (637, '最適')
# (162, '最高')
# (1340, '月額')
# (1007, '有効')
# (987, '有名')
# (1891, '有志')
# (92, '有料')
# (440, '有機')
# (1926, '朗報')
# (1225, '朝')
# (792, '期')
# (93, '期待')
# (234, '期間')
# (1876, '木')
# (1564, '未来')
# (235, '末')
# (236, '本')
# (2062, '本人')
# (899, '本体')
# (1087, '本日')
# (1368, '本来')
# (638, '本格')
# (1914, '本気')
# (1969, '本社')
# (1481, '条件')
# (793, '来場')
# (1979, '来年')
# (794, '東京')
# (1341, '東日本')
# (388, '東芝')
# (926, '板')
# (1799, '板垣')
# (713, '枚')
# (1634, '枠')
# (839, '校')
# (320, '株式会社')
# (1392, '格')
# (481, '格言')
# (749, '案内')
# (1980, '桜')
# (1718, '検知')
# (971, '検索')
# (1393, '検討')
# (582, '検証')
# (750, '業務')
# (94, '業界')
# (1298, '極')
# (862, '楽')
# (1369, '楽しみ')
# (1266, '楽天')
# (1029, '楽曲')
# (321, '概要')
# (1201, '構想')
# (1394, '構成')
# (972, '構築')
# (1443, '構造')
# (1256, '様')
# (482, '様々')
# (639, '様子')
# (1030, '標準')
# (1731, '模様')
# (389, '権')
# (1161, '横')
# (237, '機')
# (1162, '機会')
# (238, '機器')
# (2099, '機材')
# (239, '機種')
# (95, '次')
# (1070, '次世代')
# (1833, '次回')
# (163, '次期')
# (751, '次第')
# (2012, '歌')
# (1732, '正式')
# (322, '正確')
# (483, '正義')
# (1418, '正規')
# (390, '歳')
# (1614, '歴史')
# (900, '残')
# (1585, '残念')
# (1163, '段')
# (901, '段階')
# (2084, '殺到')
# (96, '毎年')
# (840, '毎日')
# (1342, '毎月')
# (714, '比')
# (1299, '比較')
# (391, '氏')
# (484, '気')
# (2014, '気分')
# (1521, '気持ち')
# (640, '気軽')
# (795, '水')
# (441, '永久')
# (240, '永遠')
# (1257, '永野')
# (1996, '汚れ')
# (323, '池田')
# (442, '決定')
# (1088, '法')
# (541, '法人')
# (485, '法則')
# (973, '波')
# (1343, '注意')
# (715, '注目')
# (2150, '洗濯')
# (1976, '洪水')
# (796, '活動')
# (443, '活用')
# (486, '活発')
# (1433, '活躍')
# (1164, '派')
# (2048, '流')
# (641, '流れ')
# (1986, '流行')
# (583, '海外')
# (716, '消費')
# (392, '液晶')
# (2001, '深夜')
# (324, '添付')
# (2141, '清浄')
# (2155, '清潔')
# (1031, '済み')
# (717, '減')
# (718, '減少')
# (1742, '温度')
# (1635, '測定')
# (988, '満足')
# (325, '満載')
# (1939, '準備')
# (1885, '演出')
# (1915, '漫画')
# (1871, '激')
# (2031, '激怒')
# (1953, '火')
# (542, '点')
# (1719, '無償')
# (97, '無料')
# (1682, '無理')
# (902, '無線')
# (1395, '無駄')
# (2085, '焦点')
# (2067, '照明')
# (2068, '爆発')
# (1652, '爆速')
# (1282, '版')
# (2131, '牧田')
# (1165, '物')
# (241, '物理')
# (989, '物語')
# (719, '特')
# (1565, '特典')
# (1126, '特別')
# (1032, '特定')
# (584, '特徴')
# (1344, '特殊')
# (1997, '特設')
# (2139, '特許')
# (1434, '特長')
# (1050, '特集')
# (1967, '状')
# (1202, '状態')
# (98, '状況')
# (543, '狙い')
# (544, '独自')
# (2025, '猫')
# (1444, '獲得')
# (642, '率')
# (2065, '現代')
# (99, '現在')
# (164, '現地')
# (585, '現場')
# (1491, '現実')
# (1322, '現状')
# (100, '現行')
# (1981, '現象')
# (752, '理由')
# (487, '理解')
# (242, '環境')
# (1536, '生')
# (1852, '生放送')
# (1663, '生活')
# (586, '生産')
# (165, '用')
# (243, '用意')
# (326, '用途')
# (1482, '申請')
# (1588, '男')
# (2121, '男子')
# (2020, '男性')
# (1089, '町')
# (1578, '画')
# (327, '画像')
# (1203, '画期的')
# (1008, '画素')
# (1492, '画質')
# (328, '画面')
# (393, '界')
# (244, '略')
# (1090, '番')
# (1290, '番号')
# (1127, '番組')
# (1636, '疑問')
# (1982, '症')
# (1213, '発')
# (2034, '発信')
# (1419, '発揮')
# (1091, '発生')
# (101, '発表')
# (1522, '発見')
# (1818, '発覚')
# (488, '発言')
# (1713, '発電')
# (1327, '発音')
# (545, '登録')
# (1840, '白')
# (489, '百')
# (245, '皆さん')
# (2053, '盛り上がり')
# (2109, '盛況')
# (797, '監督')
# (394, '目')
# (1602, '目標')
# (643, '目的')
# (1992, '目線')
# (720, '直後')
# (1396, '直感')
# (1113, '直接')
# (1790, '相当')
# (990, '相手')
# (1989, '省エネ')
# (395, '県')
# (546, '真')
# (2111, '真夏')
# (1537, '眼')
# (2116, '睡眠')
# (1897, '瞬間')
# (2078, '知り合い')
# (1785, '知識')
# (798, '研究')
# (1267, '研究所')
# (1397, '確か')
# (1743, '確保')
# (329, '確実')
# (587, '確認')
# (863, '社')
# (1128, '社会')
# (864, '社員')
# (490, '社長')
# (1877, '祭')
# (102, '祭り')
# (753, '禁止')
# (799, '私')
# (721, '秋')
# (1258, '秋葉原')
# (1886, '科学')
# (1079, '秒')
# (1615, '秘密')
# (1166, '移動')
# (722, '移行')
# (103, '程度')
# (1167, '税込')
# (1777, '種')
# (1653, '種類')
# (1744, '稼働')
# (1988, '積極')
# (1963, '空気')
# (547, '空間')
# (491, '突破')
# (1493, '立体')
# (1114, '端子')
# (246, '端末')
# (1092, '競争')
# (492, '笑い')
# (1226, '筆者')
# (1071, '等')
# (927, '筐')
# (588, '管理')
# (1179, '節約')
# (1398, '節電')
# (330, '範囲')
# (104, '簡単')
# (841, '米')
# (166, '米国')
# (1579, '精度')
# (1246, '精細')
# (1345, '系')
# (1781, '納得')
# (105, '純正')
# (247, '紙')
# (1616, '級')
# (974, '素敵')
# (928, '素材')
# (1706, '細か')
# (106, '紹介')
# (1259, '紺')
# (248, '終了')
# (1829, '組')
# (2006, '組み合わせ')
# (1778, '経済')
# (943, '経由')
# (1720, '経過')
# (589, '経験')
# (2175, '結成')
# (548, '結果')
# (167, '統合')
# (1819, '絶対')
# (1454, '継続')
# (549, '続き')
# (723, '維持')
# (1887, '綺麗')
# (944, '総合')
# (331, '線')
# (2044, '編')
# (332, '編集')
# (1782, '練習')
# (333, '縦')
# (1214, '縮小')
# (1523, '美')
# (2184, '美鈴')
# (334, '者')
# (1328, '耳')
# (2042, '肩')
# (991, '育成')
# (1033, '背景')
# (1193, '背面')
# (1300, '能力')
# (2167, '脚本')
# (842, '脳')
# (2051, '腕')
# (249, '自体')
# (1435, '自作')
# (2074, '自信')
# (493, '自分')
# (1291, '自動')
# (1625, '自動的')
# (2060, '自動車')
# (1283, '自宅')
# (1755, '自己')
# (1872, '自慢')
# (1672, '自然')
# (550, '自由')
# (2096, '自由自在')
# (335, '自社')
# (1834, '自身')
# (2091, '自転車')
# (644, '興味')
# (107, '色')
# (800, '花')
# (396, '若干')
# (1816, '苦手')
# (1882, '英会話')
# (975, '英国')
# (1800, '英憲')
# (929, '英語')
# (2082, '菌')
# (1093, '著作')
# (494, '著者')
# (1051, '薄型')
# (336, '虎の巻')
# (1645, '蛍光')
# (903, '行')
# (2107, '行列')
# (992, '行動')
# (754, '行為')
# (1215, '術')
# (551, '街')
# (2043, '衝撃')
# (337, '表')
# (2088, '表情')
# (801, '表現')
# (338, '表示')
# (1541, '表面')
# (1524, '被写体')
# (1673, '被害')
# (904, '装備')
# (108, '装着')
# (1399, '裏')
# (1538, '補正')
# (590, '製')
# (1094, '製作')
# (109, '製品')
# (110, '製造')
# (250, '複数')
# (1230, '複雑')
# (1370, '要因')
# (2016, '要注意')
# (1603, '見た目')
# (397, '見事')
# (1180, '見栄え')
# (1052, '規格')
# (865, '規模')
# (111, '視聴')
# (1952, '親')
# (2077, '観測')
# (1168, '角度')
# (930, '解像度')
# (1400, '解決')
# (1401, '解消')
# (1933, '解禁')
# (2002, '解約')
# (1034, '解説')
# (1920, '解除')
# (495, '言葉')
# (2080, '計')
# (1965, '計測')
# (1129, '計画')
# (1284, '計算')
# (398, '記念')
# (1751, '記憶')
# (1436, '記録')
# (339, '設定')
# (945, '設置')
# (591, '設計')
# (1095, '評価')
# (1721, '試用')
# (251, '話')
# (1483, '該当')
# (755, '詳細')
# (802, '誌')
# (756, '認識')
# (976, '誕生')
# (1346, '説明')
# (1204, '読者')
# (252, '誰')
# (1227, '課題')
# (1169, '調整')
# (724, '調査')
# (757, '請求')
# (2106, '講座')
# (1985, '豆')
# (2004, '豊か')
# (645, '豊富')
# (2185, '豪徳寺')
# (1437, '豪華')
# (905, '負担')
# (112, '販売')
# (113, '販売元')
# (1637, '責任')
# (2086, '買い替え')
# (1402, '買い物')
# (168, '買収')
# (552, '費')
# (114, '費用')
# (1347, '資料')
# (553, '賞')
# (253, '賢')
# (1539, '質問')
# (1115, '質量')
# (254, '購入')
# (1841, '赤')
# (1371, '赤字')
# (957, '起動')
# (1525, '足')
# (1689, '距離')
# (1638, '身近')
# (1170, '車')
# (1403, '転送')
# (906, '軽減')
# (444, '軽量')
# (1949, '近く')
# (758, '迷惑')
# (115, '追加')
# (1752, '追求')
# (1216, '送信')
# (1194, '送料')
# (1526, '逆')
# (993, '途中')
# (255, '通')
# (496, '通り')
# (725, '通信')
# (592, '通常')
# (169, '通知')
# (1072, '通話')
# (2007, '通販')
# (1678, '通過')
# (1540, '速')
# (1566, '速報')
# (1404, '速度')
# (2070, '連動')
# (116, '連携')
# (1462, '連絡')
# (1080, '連続')
# (1626, '連載')
# (1820, '逮捕')
# (1674, '週末')
# (1130, '週間')
# (1260, '進出')
# (803, '進化')
# (1131, '運動')
# (554, '運営')
# (1990, '運用')
# (2095, '運転')
# (170, '過去')
# (1860, '道')
# (1745, '道場')
# (1984, '達成')
# (1171, '違い')
# (1918, '違和感')
# (399, '選出')
# (400, '選手')
# (340, '選択')
# (907, '邪魔')
# (341, '部')
# (593, '部分')
# (1927, '部屋')
# (726, '部門')
# (804, '都')
# (2011, '都内')
# (256, '配信')
# (1779, '配布')
# (1542, '配慮')
# (646, '配置')
# (727, '重要')
# (1793, '重視')
# (1172, '重量')
# (2148, '野菜')
# (497, '量')
# (1567, '量販')
# (647, '金')
# (1348, '金額')
# (2033, '鈴木')
# (805, '銀座')
# (117, '録画')
# (1998, '鑑賞')
# (594, '長時間')
# (806, '開催')
# (257, '開始')
# (2071, '開幕')
# (171, '開発')
# (807, '開設')
# (808, '間')
# (555, '間違い')
# (595, '関係')
# (1349, '関心')
# (1350, '関西')
# (445, '閲覧')
# (446, '防塵')
# (1096, '防止')
# (447, '防水')
# (258, '限り')
# (1173, '限定')
# (259, '陣')
# (2142, '除')
# (809, '階')
# (2176, '階段')
# (958, '際')
# (810, '集')
# (1630, '集中')
# (556, '集団')
# (811, '雑誌')
# (2151, '離れ')
# (977, '雰囲気')
# (812, '電')
# (908, '電力')
# (2137, '電動')
# (260, '電子')
# (596, '電気')
# (909, '電池')
# (597, '電波')
# (910, '電源')
# (557, '電話')
# (1580, '需要')
# (1954, '震災')
# (1898, '露出')
# (261, '非常')
# (118, '面')
# (342, '面倒')
# (866, '韓国')
# (1268, '音')
# (1329, '音声')
# (813, '音楽')
# (1928, '音質')
# (1693, '音量')
# (1470, '頃')
# (598, '項目')
# (2061, '順序')
# (343, '領域')
# (843, '頭')
# (1830, '額')
# (1445, '顔')
# (1756, '類')
# (844, '風')
# (2050, '食')
# (814, '館')
# (1228, '駅')
# (599, '駆動')
# (2026, '騒ぎ')
# (2022, '騒動')
# (1817, '驚き')
# (1301, '高')
# (600, '高性能')
# (1494, '高画質')
# (931, '高級')
# (119, '高速')
# (1907, '高額')
# (1586, '髪')
# (2187, '魁')
# (401, '魅力')
# (815, '黒')
# (2179, '！—')
# (648, '％')
# (946, '）〜')
# (498, '，')
# (448, '．')
# (845, '０')
# (846, '１')
# (1646, '１つ')
# (2165, '１月')
# (2135, '１０月')
# (2152, '１２月')
# (847, '２')
# (2158, '２月')
# (994, '３')
# (1842, '３つ')
# (816, '３月')
# (1941, '４')
# (2056, '４月')
# (1617, '５')
# (1821, '６')
# (1463, '７')
# (1690, '８')
# (2030, '９')
# (2072, '９月')
# (2163, 'ｄｍｃ')
# (2154, 'ｉｐｈｏｎｅ')

# %%
# 記事の読み込み
contents = corpus.get_contents()

# 最初の記事を表示する
for item in contents.items():
    print(f"filename={item[0]}\n")
    print(item[1])
    break
# Out:
# filename=it-life-hack-6292880.txt
#
# 旧式Macで禁断のパワーアップ！最新PCやソフトを一挙にチェック【ITフラッシュバック】
# テレビやTwitterと連携できるパソコンや、プロセッサや切り替わるパソコンなど、面白いパソコンが次から次へと登場した。旧式Macの禁断ともいえるパワーアップ方法から、NECの最新PC、話題のThinkPad X1 Hybrid、新セキュリティソフトまで一挙に紹介しよう。
#
# ■インテル SSD 520をMacに装着！旧式Macはどれほど高速化するのか (上)
# インテルが最新SSD「520シリーズ」を発売した。現行SSDの中でもトップクラスの性能を誇る同製品を、旧型Macの高速化を図るというポイントでレビューしてみた。少し風変わりなレビューとなるが、どの程度の効果があるか、期待大である。
#
#
# ■http://itlifehack.jp/archives/6716997.html
# ThinkPad X1 Hybridは使用するCPUがx86(インテルCore iなど)からARMに切り替わるハイブリッドなPCだが、これと同時にOSも切り替わる。
#
#
# ■初期費用、更新費用ともに無料！ジャストシステム、ヤモリが目印のセキュリティソフト
# 現在では、多くのユーザーがパソコンにセキュリティソフトを導入しているが、その過半数は毎年5,000円程度かかる更新費用やその手続きについて不満を持っている。有料ソフトを利用するユーザーの約8割は無料のセキュリティソフトを知っているにもかかわらず、性能面で劣るのではという不安から導入を控えているという状況にある。
#
#
# ■テレビの新しい楽しみ方を提案！NECの春PCはTVとTwitterの連携
# NECは2012年2月14日、個人向けデスクトップパソコン「VALUESTAR」シリーズ3タイプ16モデルを2月16日より販売すると発表した。新商品では、よりパワフルになった録画機能に加え、TV視聴・録画機能に業界で初めて人気のTwitterを連携させた「SmartVisionつぶやきプラス」を追加するなど、TVパソコンならではの機能を搭載。スマートフォン、ホームネットワーク対応も強化し、「安心・簡単・快適」なデジタルエンターテイメントの提案として、主要モデルに対し以下の強化を行った。
#
#
# ■まるでお祭りの出荷式！レッツノートSX1の出荷が始まる
# 2月24日に発売されるLet’snote SX1/NX1の出荷式が2月8日に国内製造拠点の神戸工場で行われた。同社のパソコンとして初めてとなる出荷式で、この製品への力の入れようがわかる。
#
#
#
#
#
# 【エプソン純正インク】インクカートリッジ 6色セット IC6CL50
# エプソン
# 販売元：Amazon.co.jp
# クチコミを見る

# %%
# 特徴抽出
data_train = []
label_train = [] # 分類ラベルは、記事所在のフォルダ名になる

for file_name, content in contents.items():
    data_train.append(corpus.get_vector(dictionary, content))
    label_train.append(corpus.get_class_id(file_name))

# 分類器
estimator = RandomForestClassifier()

# 学習
estimator.fit(data_train, label_train)

# 学習したデータを予測にかける（100%のはず）
print("==== 学習データと予測データが一緒の場合")
print(estimator.score(data_train, label_train))

# 学習データとテストデータを分ける
data_train_s, data_test_s, label_train_s, label_test_s = train_test_split(data_train, label_train, test_size=0.5)

# 分類器をもう一度定義
estimator2 = RandomForestClassifier()

# 学習
estimator2.fit(data_train_s, label_train_s)
print("==== 学習データと予測データが違う場合")
print(estimator2.score(data_test_s, label_test_s))
# Out:
# ==== 学習データと予測データが一緒の場合
# 1.0
# ==== 学習データと予測データが違う場合
# 0.9792387543252595
